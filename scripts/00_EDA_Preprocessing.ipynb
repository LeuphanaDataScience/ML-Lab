# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
# %config IPCompleter.greedy=True #to enable intellisense: see it when hitting tab
from sklearn.preprocessing import LabelEncoder # integer-encoding: to transform categorical variable into integer
from sklearn.preprocessing import OneHotEncoder  # OneHot-encoding
from sklearn.compose import ColumnTransformer #needed for OneHot-encoding
from sklearn.preprocessing import LabelEncoder  #needed for OneHot-encoding
from sklearn.preprocessing import StandardScaler # to scale our data
from sklearn.decomposition import PCA #PCA

# %%
# Set seed

random.seed(2312)

# %% [markdown]
# This script file is in folder "scripts", however the working directory is ML-Lab (the parent directory). Use `cd ..` to go up one level.

# %%
cd ..

# %% [markdown]
# Check current working directory (should be based on your local directory and end with \ML-Lab)\ML-Lab\ML-Lab

# %%
ls
# Out:
#  Volume in drive D is [SSD] Documents & Education
#  Volume Serial Number is C0EF-9E46
#
#  Directory of D:\Google Drive\00_Uni Leuphana\03_3. Semester\03_ML Lab\ML-Lab
#
# 03/01/2021  00:11    <DIR>          .
# 03/01/2021  00:11    <DIR>          ..
# 31/12/2020  11:24                51 .gitignore
# 17/12/2020  17:11    <DIR>          .ipynb_checkpoints
# 03/01/2021  00:11    <DIR>          data
# 03/01/2021  00:11            49.043 ML_music_Lisa.ipynb
# 31/12/2020  10:29    <DIR>          models
# 09/11/2020  10:24                31 README.md
# 03/01/2021  00:31    <DIR>          scripts
#                3 File(s)         49.125 bytes
#                6 Dir(s)  90.989.060.096 bytes free

# %% [markdown]
# # Data prepocessing:

# %%
music_df = pd.read_csv("data\SpotifyFeatures.csv")

# %%
#check for NA's in Dataframe:
music_df.isnull().values.any()
# Out:
# False

# %%
#search for duplicates:
search = pd.DataFrame.duplicated(music_df)
print(search[search == True])#no duplicates
# Out:
# Series([], dtype: bool)

# %%
music_df.head()
# Out:
#    genre        artist_name                        track_name  \
# 0  Movie     Henri Salvador       C'est beau de faire un Show
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
# 3  Movie     Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4  Movie       Fabien Nataf                         Ouverture
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
# 3  0Gc6TVm52BwZD07Ki6tIvf           0         0.703         0.240
# 4  0IuslXpMROHdEPvSl1fTQK           4         0.950         0.331
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0        99373   0.910             0.000  C#    0.3460    -1.828  Major
# 1       137373   0.737             0.000  F#    0.1510    -5.559  Minor
# 2       170267   0.131             0.000   C    0.1030   -13.879  Minor
# 3       152427   0.326             0.000  C#    0.0985   -12.178  Major
# 4        82625   0.225             0.123   F    0.2020   -21.150  Major
#
#    speechiness    tempo time_signature  valence
# 0       0.0525  166.969            4/4    0.814
# 1       0.0868  174.003            4/4    0.816
# 2       0.0362   99.488            5/4    0.368
# 3       0.0395  171.758            4/4    0.227
# 4       0.0456  140.576            4/4    0.390

# %% [markdown]
# ### Variables:
# - popularity: ?
# - key: The estimated overall key of the track. Integers map to pitches using standard Pitch Class notation (E.g.: 0 = C)
# - mode: modality (major or minor) of a track (Major = 1 and Minor = 0) ?
# - time_signature:  estimated overall time signature (Taktangabe) of a track. Its a notational convention to specify how many beats are in each bar (or measure).
# - title: maybe there is a way to also include strings?
# - genre: one-hot encoding
# - track id: integer encoding

# %% [markdown]
# ## Transform variables:

# %% [markdown]
# ### 1. key:

# %%
music_df["key"].value_counts()
# Out:
# C     27583
# G     26390
# D     24077
# C#    23201
# A     22671
# F     20279
# B     17661
# E     17390
# A#    15526
# F#    15222
# G#    15159
# D#     7566
# Name: key, dtype: int64

# %%
## we are not using an integer encoder here because the numbers for the nodes are predetermined
# create dictionary for integer mapping:
key_mapping = {"C": 0,"G": 7,"D": 2, "C#": 1, "A": 9, "F": 5, "B": 11, "E": 4, "A#": 10, "F#": 6, "G#": 8, "D#": 3}
# map the nodes to integers:
music_df["key"] = music_df.key.map(key_mapping)
music_df.head()
# Out:
#    genre        artist_name                        track_name  \
# 0  Movie     Henri Salvador       C'est beau de faire un Show
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
# 3  Movie     Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4  Movie       Fabien Nataf                         Ouverture
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
# 3  0Gc6TVm52BwZD07Ki6tIvf           0         0.703         0.240
# 4  0IuslXpMROHdEPvSl1fTQK           4         0.950         0.331
#
#    duration_ms  energy  instrumentalness  key  liveness  loudness   mode  \
# 0        99373   0.910             0.000    1    0.3460    -1.828  Major
# 1       137373   0.737             0.000    6    0.1510    -5.559  Minor
# 2       170267   0.131             0.000    0    0.1030   -13.879  Minor
# 3       152427   0.326             0.000    1    0.0985   -12.178  Major
# 4        82625   0.225             0.123    5    0.2020   -21.150  Major
#
#    speechiness    tempo time_signature  valence
# 0       0.0525  166.969            4/4    0.814
# 1       0.0868  174.003            4/4    0.816
# 2       0.0362   99.488            5/4    0.368
# 3       0.0395  171.758            4/4    0.227
# 4       0.0456  140.576            4/4    0.390

# %% [markdown]
# ### 2. Genre:

# %%
music_df["genre"].value_counts()
# Out:
# Comedy              9681
# Soundtrack          9646
# Indie               9543
# Jazz                9441
# Pop                 9386
# Electronic          9377
# Children’s Music    9353
# Folk                9299
# Hip-Hop             9295
# Rock                9272
# Alternative         9263
# Classical           9256
# Rap                 9232
# World               9096
# Soul                9089
# Blues               9023
# R&B                 8992
# Anime               8936
# Reggaeton           8927
# Ska                 8874
# Reggae              8771
# Dance               8701
# Country             8664
# Opera               8280
# Movie               7806
# Children's Music    5403
# A Capella            119
# Name: genre, dtype: int64

# %% [markdown]
# #### Hot-encoding of variable genre:

# %% [markdown]
# First way to do it: but here you need to rename the columns (ortherwise its just numbers 1,2,....)

# %%
# # creating instance of one-hot-encoder
# enc = OneHotEncoder(handle_unknown='ignore')
# # passing bridge-types-cat column (label encoded values of bridge_types)
# enc_df = pd.DataFrame(enc.fit_transform(music_df[['genre']]).toarray())
# # merge with main df bridge_df on key values
# music_HE_df = music_df.join(enc_df)
# music_HE_df

# %% [markdown]
# Second way:

# %%
# creating dummy dataframe
dum_df = pd.get_dummies(music_df["genre"], columns=["genre"], prefix="genre_is")
music_df = music_df.join(dum_df)
music_df = music_df.drop(["genre"],1)

# %%
# Removing extra dummy
music_df = music_df.drop(columns=['genre_is_A Capella'])
music_df = music_df.drop(columns=['genre_is_A Capella'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-a15f77692da3> in <module>
#       1 # Removing extra dummy
#       2 music_df = music_df.drop(columns=['genre_is_A Capella'])
# ----> 3 music_df = music_df.drop(columns=['genre_is_A Capella'])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3919                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3920             else:
# -> 3921                 new_axis = axis.drop(labels, errors=errors)
#    3922             result = self.reindex(**{axis_name: new_axis})
#    3923
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5280         if mask.any():
#    5281             if errors != "ignore":
# -> 5282                 raise KeyError(f"{labels[mask]} not found in axis")
#    5283             indexer = indexer[~mask]
#    5284         return self.delete(indexer)
#
# KeyError: "['genre_is_A Capella'] not found in axis"

# %% [markdown]
# #### Integer-encoding of variable genre:

# %%
# Integer encoding of variable genre
# other option: hot encoding ( I think thats more the "right way to do it but than we add a column for each genre)
# https://towardsdatascience.com/categorical-encoding-techniques-93ebd18e1f24
# label_encoder = LabelEncoder()
# music_df['genre'] = label_encoder.fit_transform(music_df['genre'])
# music_df.head()

# %% [markdown]
# ## 3. Mode:

# %%
music_df["mode"].value_counts()
# Out:
# Major    151744
# Minor     80981
# Name: mode, dtype: int64

# %%
music_df["mode"] = music_df["mode"].replace({"Major": 1, "Minor":0})
music_df.rename(columns={"mode" : "Mode is Major"}, inplace=True)

# %%
music_df["Mode is Major"].value_counts()
# Out:
# 1    151744
# 0     80981
# Name: Mode is Major, dtype: int64

# %% [markdown]
# ### 4. time_signature

# %% [markdown]
# I will transform the string into a fraction (float) (if thats correct? -> music expert Chan what do you think?)

# %%
music_df["time_signature"].value_counts()
# Out:
# 4/4    200760
# 3/4     24111
# 5/4      5238
# 1/4      2608
# 0/4         8
# Name: time_signature, dtype: int64

# %%
# create dictionary for integer mapping:
time_signature_mapping = {"4/4": 1,"3/4": 3/4,"5/4": 5/4, "1/4": 1/4, "0/4": 0}
# map the nodes to integers:
music_df["time_signature"] = music_df.time_signature.map(time_signature_mapping)
music_df["time_signature"].value_counts()
# Out:
# 1.00    200760
# 0.75     24111
# 1.25      5238
# 0.25      2608
# 0.00         8
# Name: time_signature, dtype: int64

# %%
# fixing wrong encoding
music_df.time_signature.replace((1,0.75,1.25,0.25,0), ('4/4','3/4','5/4','1/4','0/4'), inplace=True)
music_df['time_signature'] = music_df['time_signature'].astype(object)
dum_df = pd.get_dummies(music_df["time_signature"], columns=["time_signature"], prefix="time_sig_is")
music_df = music_df.join(dum_df)
music_df = music_df.drop(["time_signature"],1)

# removing the extra dummy to avoid the dummy variable trap
music_df = music_df.drop(columns=['time_sig_is_0/4'])

# %% [markdown]
# ## Drop all columns we are not using (string valued):

# %% [markdown]
# I am also removing track id because I think we dont need it right now

# %%
music_df = music_df.drop(["artist_name","track_name", "track_id"],1)

# %% [markdown]
# ## Export Encoded Data

# %%
pd.DataFrame.to_csv(music_df, "data/EncodedData.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-27-c472a67ac896> in <module>
# ----> 1 pd.DataFrame.to_csv(music_df, "data/EncodedData.csv")
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors)
#    3168             decimal=decimal,
#    3169         )
# -> 3170         formatter.save()
#    3171
#    3172         if path_or_buf is None:
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     183             close = False
#     184         else:
# --> 185             f, handles = get_handle(
#     186                 self.path_or_buf,
#     187                 self.mode,
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors)
#     491         if encoding:
#     492             # Encoding
# --> 493             f = open(path_or_buf, mode, encoding=encoding, errors=errors, newline="")
#     494         elif is_text:
#     495             # No explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/EncodedData.csv'

# %% [markdown]
# # Data Analysis

# %% [markdown]
# ## 1. First Overview

# %%
print(music_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 232725 entries, 0 to 232724
# Data columns (total 43 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   popularity                 232725 non-null  int64
#  1   acousticness               232725 non-null  float64
#  2   danceability               232725 non-null  float64
#  3   duration_ms                232725 non-null  int64
#  4   energy                     232725 non-null  float64
#  5   instrumentalness           232725 non-null  float64
#  6   key                        232725 non-null  int64
#  7   liveness                   232725 non-null  float64
#  8   loudness                   232725 non-null  float64
#  9   Mode is Major              232725 non-null  int64
#  10  speechiness                232725 non-null  float64
#  11  tempo                      232725 non-null  float64
#  12  valence                    232725 non-null  float64
#  13  genre_is_Alternative       232725 non-null  uint8
#  14  genre_is_Anime             232725 non-null  uint8
#  15  genre_is_Blues             232725 non-null  uint8
#  16  genre_is_Children's Music  232725 non-null  uint8
#  17  genre_is_Children’s Music  232725 non-null  uint8
#  18  genre_is_Classical         232725 non-null  uint8
#  19  genre_is_Comedy            232725 non-null  uint8
#  20  genre_is_Country           232725 non-null  uint8
#  21  genre_is_Dance             232725 non-null  uint8
#  22  genre_is_Electronic        232725 non-null  uint8
#  23  genre_is_Folk              232725 non-null  uint8
#  24  genre_is_Hip-Hop           232725 non-null  uint8
#  25  genre_is_Indie             232725 non-null  uint8
#  26  genre_is_Jazz              232725 non-null  uint8
#  27  genre_is_Movie             232725 non-null  uint8
#  28  genre_is_Opera             232725 non-null  uint8
#  29  genre_is_Pop               232725 non-null  uint8
#  30  genre_is_R&B               232725 non-null  uint8
#  31  genre_is_Rap               232725 non-null  uint8
#  32  genre_is_Reggae            232725 non-null  uint8
#  33  genre_is_Reggaeton         232725 non-null  uint8
#  34  genre_is_Rock              232725 non-null  uint8
#  35  genre_is_Ska               232725 non-null  uint8
#  36  genre_is_Soul              232725 non-null  uint8
#  37  genre_is_Soundtrack        232725 non-null  uint8
#  38  genre_is_World             232725 non-null  uint8
#  39  time_sig_is_1/4            232725 non-null  uint8
#  40  time_sig_is_3/4            232725 non-null  uint8
#  41  time_sig_is_4/4            232725 non-null  uint8
#  42  time_sig_is_5/4            232725 non-null  uint8
# dtypes: float64(9), int64(4), uint8(30)
# memory usage: 29.7 MB
# None

# %% [markdown]
# ## 2. Plots

# %%
fig = plt.figure(figsize = (7,7))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Popularity', fontsize = 15)
ax.set_ylabel('Count', fontsize = 15)
ax.set_title('Histogram', fontsize = 20)
plt.hist(music_df["popularity"], facecolor = "pink", edgecolor = "r")
ax.grid()

# %% [markdown]
# ## 3. Correlation:

# %%
pd.DataFrame.corr(music_df)
# Out:
#                            popularity  acousticness  danceability  \
# popularity                   1.000000     -0.381295      0.256564
# acousticness                -0.381295      1.000000     -0.364546
# danceability                 0.256564     -0.364546      1.000000
# duration_ms                  0.002348      0.011203     -0.125781
# energy                       0.248922     -0.725576      0.325807
# instrumentalness            -0.210983      0.316154     -0.364941
# key                          0.012190     -0.026297      0.030046
# liveness                    -0.167995      0.069004     -0.041684
# loudness                     0.363011     -0.690202      0.438668
# Mode is Major               -0.070550      0.055907     -0.061890
# speechiness                 -0.151076      0.150935      0.134560
# tempo                        0.081039     -0.238247      0.021939
# time_signature               0.142269     -0.222495      0.190614
# valence                      0.060076     -0.325798      0.547154
# genre_is_A Capella          -0.039573      0.029416     -0.017318
# genre_is_Alternative         0.101698     -0.118364     -0.013674
# genre_is_Anime              -0.185313     -0.046028     -0.088577
# genre_is_Blues              -0.070493     -0.023052     -0.028277
# genre_is_Children's Music   -0.312534      0.097003      0.118870
# genre_is_Children’s Music    0.152222     -0.118464     -0.013804
# genre_is_Classical          -0.132531      0.286995     -0.272376
# genre_is_Comedy             -0.226604      0.249308      0.005246
# genre_is_Country             0.053760     -0.054535      0.024022
# genre_is_Dance               0.174952     -0.119809      0.089007
# genre_is_Electronic         -0.034598     -0.143651      0.071952
# genre_is_Folk                0.098839      0.054423     -0.029774
# genre_is_Hip-Hop             0.193937     -0.110609      0.180707
# genre_is_Indie               0.154309     -0.021768      0.013878
# genre_is_Jazz               -0.003427      0.075956      0.034646
# genre_is_Movie              -0.296531      0.172649     -0.063412
# genre_is_Opera              -0.293459      0.312192     -0.272897
# genre_is_Pop                 0.286972     -0.083061      0.094844
# genre_is_R&B                 0.123231     -0.045402      0.094790
# genre_is_Rap                 0.216834     -0.114853      0.156455
# genre_is_Reggae             -0.060253     -0.101959      0.154503
# genre_is_Reggaeton          -0.037162     -0.084240      0.190347
# genre_is_Rock                0.207083     -0.098835     -0.017639
# genre_is_Ska                -0.136989     -0.150875     -0.029570
# genre_is_Soul                0.065393     -0.004479      0.068732
# genre_is_Soundtrack         -0.081997      0.204438     -0.323495
# genre_is_World              -0.062128      0.014087     -0.120689
#
#                            duration_ms    energy  instrumentalness       key  \
# popularity                    0.002348  0.248922         -0.210983  0.012190
# acousticness                  0.011203 -0.725576          0.316154 -0.026297
# danceability                 -0.125781  0.325807         -0.364941  0.030046
# duration_ms                   1.000000 -0.030550          0.076021  0.003795
# energy                       -0.030550  1.000000         -0.378957  0.032128
# instrumentalness              0.076021 -0.378957          1.000000 -0.017168
# key                           0.003795  0.032128         -0.017168  1.000000
# liveness                      0.023783  0.192801         -0.134198  0.002685
# loudness                     -0.047618  0.816088         -0.506320  0.026300
# Mode is Major                -0.011555 -0.041302         -0.049823 -0.142132
# speechiness                  -0.016171  0.145120         -0.177147  0.012279
# tempo                        -0.028456  0.228774         -0.104133 -0.003073
# time_signature                0.000942  0.185699         -0.098657  0.011189
# valence                      -0.141811  0.436771         -0.307522  0.038078
# genre_is_A Capella           -0.005830 -0.027528         -0.010519  0.001134
# genre_is_Alternative         -0.003220  0.108626         -0.058502  0.002114
# genre_is_Anime               -0.008712  0.071600          0.087312 -0.000205
# genre_is_Blues                0.028385  0.026844         -0.035240  0.003202
# genre_is_Children's Music    -0.119767 -0.101867         -0.002408 -0.021267
# genre_is_Children’s Music    -0.004418  0.105366         -0.063504  0.003275
# genre_is_Classical            0.128710 -0.303571          0.303242 -0.014715
# genre_is_Comedy               0.000320  0.083140         -0.101652  0.001859
# genre_is_Country             -0.029570  0.048785         -0.092676  0.001302
# genre_is_Dance               -0.014677  0.095084         -0.073458  0.000039
# genre_is_Electronic           0.058701  0.130926          0.137147  0.009760
# genre_is_Folk                 0.001172 -0.061349         -0.042698 -0.008328
# genre_is_Hip-Hop             -0.025965  0.055987         -0.092360 -0.001652
# genre_is_Indie               -0.019076  0.007884         -0.043016  0.000298
# genre_is_Jazz                 0.052771 -0.076631          0.142424  0.005187
# genre_is_Movie               -0.038715 -0.141605         -0.014075 -0.008890
# genre_is_Opera                0.038820 -0.293206          0.053105 -0.009229
# genre_is_Pop                 -0.024585  0.055442         -0.089175 -0.001469
# genre_is_R&B                 -0.015801 -0.005106         -0.081274  0.006866
# genre_is_Rap                 -0.026092  0.061378         -0.093298 -0.000699
# genre_is_Reggae               0.007290  0.048670         -0.070808  0.020390
# genre_is_Reggaeton           -0.005181  0.134847         -0.095409  0.019678
# genre_is_Rock                 0.003221  0.087148         -0.063925 -0.003730
# genre_is_Ska                 -0.072945  0.184875         -0.060232  0.001714
# genre_is_Soul                -0.000692 -0.029424         -0.057268  0.008499
# genre_is_Soundtrack          -0.074324 -0.276132          0.436335 -0.020012
# genre_is_World                0.136005 -0.049380          0.057007  0.001234
#
#                            liveness  loudness  Mode is Major  ...  \
# popularity                -0.167995  0.363011      -0.070550  ...
# acousticness               0.069004 -0.690202       0.055907  ...
# danceability              -0.041684  0.438668      -0.061890  ...
# duration_ms                0.023783 -0.047618      -0.011555  ...
# energy                     0.192801  0.816088      -0.041302  ...
# instrumentalness          -0.134198 -0.506320      -0.049823  ...
# key                        0.002685  0.026300      -0.142132  ...
# liveness                   1.000000  0.045686       0.018459  ...
# loudness                   0.045686  1.000000      -0.027109  ...
# Mode is Major              0.018459 -0.027109       1.000000  ...
# speechiness                0.510147 -0.002273      -0.026039  ...
# tempo                     -0.051355  0.228364       0.011741  ...
# time_signature            -0.065233  0.204395      -0.021003  ...
# valence                    0.011804  0.399901       0.001714  ...
# genre_is_A Capella        -0.008908 -0.015425       0.003754  ...
# genre_is_Alternative      -0.018509  0.102817      -0.007511  ...
# genre_is_Anime            -0.022795  0.055038      -0.012889  ...
# genre_is_Blues             0.018350  0.017280       0.024847  ...
# genre_is_Children's Music -0.038968 -0.053252       0.070991  ...
# genre_is_Children’s Music -0.020635  0.103818      -0.005578  ...
# genre_is_Classical        -0.053581 -0.406297       0.005853  ...
# genre_is_Comedy            0.535640 -0.073615       0.017470  ...
# genre_is_Country          -0.027564  0.073048       0.092144  ...
# genre_is_Dance            -0.027092  0.115511      -0.022365  ...
# genre_is_Electronic       -0.005171  0.086563      -0.051705  ...
# genre_is_Folk             -0.045517 -0.010217       0.055996  ...
# genre_is_Hip-Hop          -0.014261  0.092138      -0.041306  ...
# genre_is_Indie            -0.048068  0.057046       0.015816  ...
# genre_is_Jazz             -0.043199 -0.056241      -0.051433  ...
# genre_is_Movie             0.012878 -0.105046       0.041899  ...
# genre_is_Opera             0.007996 -0.312845       0.049634  ...
# genre_is_Pop              -0.036232  0.105077      -0.012700  ...
# genre_is_R&B              -0.040100  0.065937      -0.053362  ...
# genre_is_Rap              -0.016474  0.098263      -0.039265  ...
# genre_is_Reggae           -0.021892  0.067695      -0.030646  ...
# genre_is_Reggaeton        -0.007554  0.122996      -0.058932  ...
# genre_is_Rock             -0.028796  0.077566       0.038391  ...
# genre_is_Ska               0.028583  0.112766       0.037395  ...
# genre_is_Soul             -0.036357  0.023644      -0.038152  ...
# genre_is_Soundtrack       -0.081233 -0.336720      -0.042791  ...
# genre_is_World             0.013004 -0.038181       0.041527  ...
#
#                            genre_is_Pop  genre_is_R&B  genre_is_Rap  \
# popularity                     0.286972      0.123231      0.216834
# acousticness                  -0.083061     -0.045402     -0.114853
# danceability                   0.094844      0.094790      0.156455
# duration_ms                   -0.024585     -0.015801     -0.026092
# energy                         0.055442     -0.005106      0.061378
# instrumentalness              -0.089175     -0.081274     -0.093298
# key                           -0.001469      0.006866     -0.000699
# liveness                      -0.036232     -0.040100     -0.016474
# loudness                       0.105077      0.065937      0.098263
# Mode is Major                 -0.012700     -0.053362     -0.039265
# speechiness                   -0.014147      0.000247      0.073863
# tempo                          0.023283     -0.008388      0.022589
# time_signature                 0.031609      0.028401      0.043859
# valence                        0.020853     -0.003523      0.000783
# genre_is_A Capella            -0.004637     -0.004534     -0.004597
# genre_is_Alternative          -0.041738     -0.040817     -0.041380
# genre_is_Anime                -0.040965     -0.040060     -0.040613
# genre_is_Blues                -0.041172     -0.040263     -0.040818
# genre_is_Children's Music     -0.031605     -0.030907     -0.031334
# genre_is_Children’s Music     -0.041949     -0.041023     -0.041589
# genre_is_Classical            -0.041722     -0.040801     -0.041364
# genre_is_Comedy               -0.042709     -0.041766     -0.042343
# genre_is_Country              -0.040312     -0.039422     -0.039966
# genre_is_Dance                -0.040401     -0.039509     -0.040055
# genre_is_Electronic           -0.042005     -0.041078     -0.041644
# genre_is_Folk                 -0.041822     -0.040899     -0.041464
# genre_is_Hip-Hop              -0.041813     -0.040890     -0.041454
# genre_is_Indie                -0.042391     -0.041455     -0.042027
# genre_is_Jazz                 -0.042154     -0.041223     -0.041792
# genre_is_Movie                -0.038191     -0.037348     -0.037863
# genre_is_Opera                -0.039375     -0.038506     -0.039037
# genre_is_Pop                   1.000000     -0.041098     -0.041665
# genre_is_R&B                  -0.041098      1.000000     -0.040745
# genre_is_Rap                  -0.041665     -0.040745      1.000000
# genre_is_Reggae               -0.040570     -0.039674     -0.040222
# genre_is_Reggaeton            -0.040943     -0.040039     -0.040592
# genre_is_Rock                 -0.041759     -0.040837     -0.041401
# genre_is_Ska                  -0.040817     -0.039916     -0.040467
# genre_is_Soul                 -0.041328     -0.040416     -0.040974
# genre_is_Soundtrack           -0.042629     -0.041688     -0.042263
# genre_is_World                -0.041345     -0.040432     -0.040990
#
#                            genre_is_Reggae  genre_is_Reggaeton  genre_is_Rock  \
# popularity                       -0.060253           -0.037162       0.207083
# acousticness                     -0.101959           -0.084240      -0.098835
# danceability                      0.154503            0.190347      -0.017639
# duration_ms                       0.007290           -0.005181       0.003221
# energy                            0.048670            0.134847       0.087148
# instrumentalness                 -0.070808           -0.095409      -0.063925
# key                               0.020390            0.019678      -0.003730
# liveness                         -0.021892           -0.007554      -0.028796
# loudness                          0.067695            0.122996       0.077566
# Mode is Major                    -0.030646           -0.058932       0.038391
# speechiness                      -0.004909            0.007375      -0.073678
# tempo                             0.003176            0.021466       0.032719
# time_signature                    0.048999            0.044474       0.025384
# valence                           0.171025            0.157066       0.048717
# genre_is_A Capella               -0.004476           -0.004517      -0.004607
# genre_is_Alternative             -0.040292           -0.040663      -0.041473
# genre_is_Anime                   -0.039546           -0.039910      -0.040705
# genre_is_Blues                   -0.039745           -0.040111      -0.040910
# genre_is_Children's Music        -0.030510           -0.030791      -0.031404
# genre_is_Children’s Music        -0.040495           -0.040868      -0.041683
# genre_is_Classical               -0.040276           -0.040647      -0.041457
# genre_is_Comedy                  -0.041230           -0.041609      -0.042438
# genre_is_Country                 -0.038915           -0.039274      -0.040056
# genre_is_Dance                   -0.039002           -0.039361      -0.040145
# genre_is_Electronic              -0.040550           -0.040923      -0.041738
# genre_is_Folk                    -0.040374           -0.040745      -0.041557
# genre_is_Hip-Hop                 -0.040364           -0.040736      -0.041548
# genre_is_Indie                   -0.040922           -0.041299      -0.042122
# genre_is_Jazz                    -0.040694           -0.041068      -0.041886
# genre_is_Movie                   -0.036868           -0.037207      -0.037949
# genre_is_Opera                   -0.038011           -0.038361      -0.039125
# genre_is_Pop                     -0.040570           -0.040943      -0.041759
# genre_is_R&B                     -0.039674           -0.040039      -0.040837
# genre_is_Rap                     -0.040222           -0.040592      -0.041401
# genre_is_Reggae                   1.000000           -0.039525      -0.040312
# genre_is_Reggaeton               -0.039525            1.000000      -0.040683
# genre_is_Rock                    -0.040312           -0.040683       1.000000
# genre_is_Ska                     -0.039403           -0.039765      -0.040558
# genre_is_Soul                    -0.039896           -0.040264      -0.041066
# genre_is_Soundtrack              -0.041152           -0.041531      -0.042358
# genre_is_World                   -0.039912           -0.040280      -0.041082
#
#                            genre_is_Ska  genre_is_Soul  genre_is_Soundtrack  \
# popularity                    -0.136989       0.065393            -0.081997
# acousticness                  -0.150875      -0.004479             0.204438
# danceability                  -0.029570       0.068732            -0.323495
# duration_ms                   -0.072945      -0.000692            -0.074324
# energy                         0.184875      -0.029424            -0.276132
# instrumentalness              -0.060232      -0.057268             0.436335
# key                            0.001714       0.008499            -0.020012
# liveness                       0.028583      -0.036357            -0.081233
# loudness                       0.112766       0.023644            -0.336720
# Mode is Major                  0.037395      -0.038152            -0.042791
# speechiness                   -0.033922      -0.041548            -0.086210
# tempo                          0.075785      -0.015294            -0.091411
# time_signature                 0.036116       0.011158            -0.089877
# valence                        0.152013       0.019880            -0.269006
# genre_is_A Capella            -0.004503      -0.004560            -0.004703
# genre_is_Alternative          -0.040537      -0.041045            -0.042337
# genre_is_Anime                -0.039786      -0.040285            -0.041552
# genre_is_Blues                -0.039987      -0.040488            -0.041762
# genre_is_Children's Music     -0.030696      -0.031080            -0.032058
# genre_is_Children’s Music     -0.040742      -0.041252            -0.042551
# genre_is_Classical            -0.040521      -0.041029            -0.042320
# genre_is_Comedy               -0.041481      -0.042000            -0.043322
# genre_is_Country              -0.039152      -0.039643            -0.040890
# genre_is_Dance                -0.039239      -0.039731            -0.040981
# genre_is_Electronic           -0.040796      -0.041307            -0.042607
# genre_is_Folk                 -0.040619      -0.041128            -0.042422
# genre_is_Hip-Hop              -0.040610      -0.041119            -0.042413
# genre_is_Indie                -0.041171      -0.041687            -0.042999
# genre_is_Jazz                 -0.040941      -0.041454            -0.042759
# genre_is_Movie                -0.037092      -0.037557            -0.038739
# genre_is_Opera                -0.038242      -0.038721            -0.039940
# genre_is_Pop                  -0.040817      -0.041328            -0.042629
# genre_is_R&B                  -0.039916      -0.040416            -0.041688
# genre_is_Rap                  -0.040467      -0.040974            -0.042263
# genre_is_Reggae               -0.039403      -0.039896            -0.041152
# genre_is_Reggaeton            -0.039765      -0.040264            -0.041531
# genre_is_Rock                 -0.040558      -0.041066            -0.042358
# genre_is_Ska                   1.000000      -0.040139            -0.041402
# genre_is_Soul                 -0.040139       1.000000            -0.041921
# genre_is_Soundtrack           -0.041402      -0.041921             1.000000
# genre_is_World                -0.040155      -0.040658            -0.041938
#
#                            genre_is_World
# popularity                      -0.062128
# acousticness                     0.014087
# danceability                    -0.120689
# duration_ms                      0.136005
# energy                          -0.049380
# instrumentalness                 0.057007
# key                              0.001234
# liveness                         0.013004
# loudness                        -0.038181
# Mode is Major                    0.041527
# speechiness                     -0.081532
# tempo                            0.014063
# time_signature                  -0.010743
# valence                         -0.123505
# genre_is_A Capella              -0.004562
# genre_is_Alternative            -0.041062
# genre_is_Anime                  -0.040301
# genre_is_Blues                  -0.040504
# genre_is_Children's Music       -0.031093
# genre_is_Children’s Music       -0.041269
# genre_is_Classical              -0.041045
# genre_is_Comedy                 -0.042017
# genre_is_Country                -0.039659
# genre_is_Dance                  -0.039746
# genre_is_Electronic             -0.041324
# genre_is_Folk                   -0.041145
# genre_is_Hip-Hop                -0.041135
# genre_is_Indie                  -0.041704
# genre_is_Jazz                   -0.041471
# genre_is_Movie                  -0.037572
# genre_is_Opera                  -0.038737
# genre_is_Pop                    -0.041345
# genre_is_R&B                    -0.040432
# genre_is_Rap                    -0.040990
# genre_is_Reggae                 -0.039912
# genre_is_Reggaeton              -0.040280
# genre_is_Rock                   -0.041082
# genre_is_Ska                    -0.040155
# genre_is_Soul                   -0.040658
# genre_is_Soundtrack             -0.041938
# genre_is_World                   1.000000
#
# [41 rows x 41 columns]

# %% [markdown]
# ## 4. PCA

# %% [markdown]
# Standardize the Data:

# %%
music_df_scaled = music_df.copy()
#make list of all column names
col_names = list(music_df.columns.values)

features = music_df_scaled[col_names]
scaler = StandardScaler().fit(features.values)
features = scaler.transform(features.values)
music_df_scaled[col_names] = features
music_df_scaled.head()
# Out:
#    popularity  acousticness  danceability  duration_ms    energy  \
# 0   -2.261007      0.683376     -0.890935    -1.141368  1.286908
# 1   -2.206031     -0.345467      0.191994    -0.821867  0.630249
# 2   -2.096080      1.644570      0.585296    -0.545298 -1.669954
# 3   -2.261007      0.942701     -1.693703    -0.695295 -0.929789
# 4   -2.041104      1.638932     -1.203422    -1.282184 -1.313157
#
#    instrumentalness       key  liveness  loudness  Mode is Major  ...  \
# 0         -0.489819 -1.185135  0.660661  1.290703       0.730526  ...
# 1         -0.489819  0.217500 -0.322835  0.668683      -1.368876  ...
# 2         -0.489819 -1.465663 -0.564927 -0.718402      -1.368876  ...
# 3         -0.489819 -1.185135 -0.587623 -0.434817       0.730526  ...
# 4         -0.083566 -0.063027 -0.065613 -1.930601       0.730526  ...
#
#    genre_is_Pop  genre_is_R&B  genre_is_Rap  genre_is_Reggae  \
# 0     -0.205002     -0.200476     -0.203243          -0.1979
# 1     -0.205002     -0.200476     -0.203243          -0.1979
# 2     -0.205002     -0.200476     -0.203243          -0.1979
# 3     -0.205002     -0.200476     -0.203243          -0.1979
# 4     -0.205002     -0.200476     -0.203243          -0.1979
#
#    genre_is_Reggaeton  genre_is_Rock  genre_is_Ska  genre_is_Soul  \
# 0           -0.199721      -0.203701     -0.199104      -0.201598
# 1           -0.199721      -0.203701     -0.199104      -0.201598
# 2           -0.199721      -0.203701     -0.199104      -0.201598
# 3           -0.199721      -0.203701     -0.199104      -0.201598
# 4           -0.199721      -0.203701     -0.199104      -0.201598
#
#    genre_is_Soundtrack  genre_is_World
# 0            -0.207943       -0.201679
# 1            -0.207943       -0.201679
# 2            -0.207943       -0.201679
# 3            -0.207943       -0.201679
# 4            -0.207943       -0.201679
#
# [5 rows x 41 columns]

# %% [markdown]
# Transform the popularity variable into ranges:

# %%
bins = [0,10, 20, 30, 45, 50, 60, 70, 80, 90, 100]
Y = pd.cut(music_df["popularity"],bins, include_lowest=True, right = True) 
# Y['popularity'] = Y['popularity'].apply(str)
# Y.popularity = Y.popularity.astype(str)

# %%
# drop the target variable popularity nd ID before we apply PCA 
music_df_scaled = music_df_scaled.drop(["popularity"],1)

# %%
#PCA:
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(music_df_scaled)
principalDf = pd.DataFrame(data = principalComponents, columns = ['principal component 1', 'principal component 2'])
finalDf = pd.concat([principalDf, Y], axis = 1)
finalDf.popularity = finalDf.popularity.apply(str)# change buckets to string for PCA plot to work
finalDf.head()
# Out:
#    principal component 1  principal component 2      popularity
# 0              -1.041859               0.190436  (-0.001, 10.0]
# 1              -1.316615              -0.358412  (-0.001, 10.0]
# 2               1.456684              -0.321205  (-0.001, 10.0]
# 3               1.684552              -0.499234  (-0.001, 10.0]
# 4               2.578971               0.016420  (-0.001, 10.0]

# %%
fig = plt.figure(figsize = (12,12))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
targets = ["(-0.001, 10.0]", "(10.0, 20.0]","(20.0, 30.0] ","(30.0, 40.0]","(40.0, 50.0]","(50.0, 60.0]" ,"(60.0, 70.0] ","(70.0, 80.0]","(80.0, 90.0] ","(90.0, 100.0]"]
colors = ['r', 'g', 'b', "c", "m", "y", "gray", "brown","pink","k"]
for target, color in zip(targets,colors):
    indicesToKeep = finalDf['popularity'] == target
    ax.scatter(finalDf.loc[indicesToKeep, 'principal component 1']
               , finalDf.loc[indicesToKeep, 'principal component 2']
               , c = color
               , s = 50)
ax.legend(targets)
ax.grid()

# %%
#Transform the popularity variable into ranges:
bins2 = [0,25,50,75,100]
Y2 = pd.cut(music_df["popularity"],bins2, include_lowest=True, right = True)

# %%
#PCA:
finalDf2 = pd.concat([principalDf, Y2], axis = 1)
finalDf2.popularity = finalDf2.popularity.apply(str)# change buckets to string for PCA plot to work
finalDf.head()
# Out:
#    principal component 1  principal component 2      popularity
# 0              -1.041859               0.190436  (-0.001, 10.0]
# 1              -1.316615              -0.358412  (-0.001, 10.0]
# 2               1.456684              -0.321205  (-0.001, 10.0]
# 3               1.684552              -0.499234  (-0.001, 10.0]
# 4               2.578971               0.016420  (-0.001, 10.0]

# %%
Y2.value_counts()
# Out:
# (25.0, 50.0]      107246
# (50.0, 75.0]       76646
# (-0.001, 25.0]     45877
# (75.0, 100.0]       2956
# Name: popularity, dtype: int64

# %%
fig2 = plt.figure(figsize = (12,12))
ax2 = fig2.add_subplot(1,1,1) 
ax2.set_xlabel('Principal Component 1', fontsize = 15)
ax2.set_ylabel('Principal Component 2', fontsize = 15)
ax2.set_title('2 component PCA', fontsize = 20)
targets2 = ["(-0.001, 25.0]", "(25.0, 50.0] ","(50.0, 75.0]","(75.0, 100.0]"]
colors2 = ['r', 'g', 'b', "k"]
for target, color in zip(targets2,colors2):
    indicesToKeep2 = finalDf2['popularity'] == target
    ax2.scatter(finalDf2.loc[indicesToKeep2, 'principal component 1']
               , finalDf2.loc[indicesToKeep2, 'principal component 2']
               , c = color
               , s = 50)
ax2.legend(targets2)
ax2.grid()

# %% [raw]
# green bin doesnt appear... new try with equally dispersed bins

# %%
#Transform the popularity variable into ranges:
Y3 = pd.qcut(music_df["popularity"],q=4)

# %%
#PCA:
principalDf3 = pd.DataFrame(data = principalComponents, columns = ['principal component 1', 'principal component 2'])
finalDf3 = pd.concat([principalDf3, Y3], axis = 1)
finalDf3.popularity = finalDf3.popularity.apply(str)# change buckets to string for PCA plot to work
finalDf3.head()
# Out:
#    principal component 1  principal component 2      popularity
# 0              -1.041859               0.190436  (-0.001, 29.0]
# 1              -1.316615              -0.358412  (-0.001, 29.0]
# 2               1.456684              -0.321205  (-0.001, 29.0]
# 3               1.684552              -0.499234  (-0.001, 29.0]
# 4               2.578971               0.016420  (-0.001, 29.0]

# %%
#look at the size of the new (equally distributed) bins
Y3.value_counts()
# Out:
# (43.0, 55.0]      60346
# (-0.001, 29.0]    60339
# (29.0, 43.0]      58304
# (55.0, 100.0]     53736
# Name: popularity, dtype: int64

# %%
fig3 = plt.figure(figsize = (12,12))
ax3 = fig3.add_subplot(1,1,1) 
ax3.set_xlabel('Principal Component 1', fontsize = 15)
ax3.set_ylabel('Principal Component 2', fontsize = 15)
ax3.set_title('2 component PCA', fontsize = 20)
targets3 = ["(-0.001, 29.0]", "(29.0, 43.0] ","(43.0, 55.0]","(55.0, 100.0]"]
colors3 = ['r', 'g', 'b', "k"]
for target, color in zip(targets3,colors3):
    indicesToKeep3 = finalDf3['popularity'] == target
    ax3.scatter(finalDf3.loc[indicesToKeep3, 'principal component 1']
               , finalDf3.loc[indicesToKeep3, 'principal component 2']
               , c = color
               , s = 50)
ax3.legend(targets3)
ax3.grid()

# %% [markdown]
# # Model:

# %% [markdown]
# ## 1. Multilayer perceptron

# %% [markdown]
# https://www.kaggle.com/sebastienmurphy/mlp-regressor-on-movie-dataset

# %%
from sklearn.model_selection import train_test_split 
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import MinMaxScaler
from sklearn import datasets
from sklearn.neural_network import MLPRegressor

# %%
X, y = music_df.drop(["popularity"],1) , music_df["popularity"]

# %% [markdown]
# ### Split data into training and test set:

# %%
X_tr, X_t, y_tr, y_t = train_test_split(X, y, 
                                        test_size=0.2, 
                                        random_state=0)

# %%
# Export to csv

X_tr.to_csv("data/X_tr.csv")
X_t.to_csv("data/X_t.csv")
y_tr.to_csv("data/y_tr.csv")
y_t.to_csv("data/y_t.csv")

# %% [markdown]
# ### Transform the data:

# %% [markdown]
# Options:
# a) Standardize: For better performance of the algorithms and PCA standardize the data (mean = 0, variance = 1)
# b) rescale the data into (-1,1)

# %% [markdown]
# a) Standardize:

# %%
scaling = StandardScaler().fit(X_tr)
X_tr = scaling.transform(X_tr)
X_t = scaling.transform(X_t)

# %% [markdown]
# Scaling:

# %%
# scaling = MinMaxScaler(feature_range=(-1, 1)).fit(X_tr)
# X_tr = scaling.transform(X_tr)
# X_t = scaling.transform(X_t)

# %% [markdown]
# Model:

# %% [markdown]
# Define MLP function:
# - Solver = adam: for large datasets
# - number of neurons in each layer: hidden_layer_sizes = (100,100) (2 layers which 100 nodes each)
#   -> should be choosen as power of 2 (more efficient)
# - activation function: activation='relu' (the rectified linear unit function, returns f(x) = max(0, x))
# - shuffle=True: shuffle the data
# - tol=1e-4: Tolerance for the optimization
# - random_state=1: for reproducibility of results
# - max_iter: maximum number of iterations (default=200)

# %%
MLP = MLPRegressor(hidden_layer_sizes=(32,), 
                   activation='relu', 
                   solver='adam',
                   shuffle=True,
                   tol=1e-4,
                   random_state=1,
                   max_iter=1000)

# %% [markdown]
# Calculate test results:

# %%
cv = cross_val_score(MLP, X_tr, y_tr, cv=10)
test_score = MLP.fit(X_tr, y_tr).score(X_t, y_t)
print('CV accuracy score: %0.3f' % np.mean(cv))
print('Test accuracy score: %0.3f' % (test_score))
# Out:
# C:\Users\93cha\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:587: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")

# %%
y_t
# Out:
# 134848    35
# 43959     50
# 135390    27
# 104126    13
# 58631     26
#           ..
# 53098     32
# 61551     49
# 225066    56
# 231201    49
# 208653    39
# Name: popularity, Length: 46545, dtype: int64
